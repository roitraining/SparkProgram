# %% [markdown]
# Setup the Spark environment

# %%
import sys
sys.path.append('/home/student/ROI/SparkProgram')
from initspark import *
sc, spark, conf = initspark()

# %% [markdown]
# Turn a simple RDD into a dataframe

# %%
x = sc.parallelize([(1,'alpha'),(2,'beta')])
x0 = spark.createDataFrame(x)
x0.show()
# Out:
# +---+-----+
# | _1|   _2|
# +---+-----+
# |  1|alpha|
# |  2| beta|
# +---+-----+

# %% [markdown]
# Give the dataframe meaningful column names

# %%
x1 = spark.createDataFrame(x, schema=['ID','Name'])
x1.show()
print(x1)
# Out:
# +---+-----+
# | ID| Name|
# +---+-----+
# |  1|alpha|
# |  2| beta|
# +---+-----+
#
# DataFrame[ID: bigint, Name: string]

# %% [markdown]
# Give a dataframe a schema with column names and data types

# %%
x2 = spark.createDataFrame(x, 'ID:int, Name:string')
x2.show()
print(x2)
# Out:
# +---+-----+
# | ID| Name|
# +---+-----+
# |  1|alpha|
# |  2| beta|
# +---+-----+
#
# DataFrame[ID: int, Name: string]

# %% [markdown]
# Load a text file into a RDD and clean it up as before

# %%
filename = '/home/student/ROI/SparkProgram/datasets/finance/CreditCard.csv'
cc = sc.textFile(filename)
first = cc.first()
cc = cc.filter(lambda x : x != first)
cc.take(10)
# Out:
# ['"Delhi, India",29-Oct-14,Gold,Bills,F,82475',
#  '"Greater Mumbai, India",22-Aug-14,Platinum,Bills,F,32555',
#  '"Bengaluru, India",27-Aug-14,Silver,Bills,F,101738',
#  '"Greater Mumbai, India",12-Apr-14,Signature,Bills,F,123424',
#  '"Bengaluru, India",5-May-15,Gold,Bills,F,171574',
#  '"Delhi, India",8-Sep-14,Silver,Bills,F,100036',
#  '"Delhi, India",24-Feb-15,Gold,Bills,F,143250',
#  '"Greater Mumbai, India",26-Jun-14,Platinum,Bills,F,150980',
#  '"Delhi, India",28-Mar-14,Silver,Bills,F,192247',
#  '"Delhi, India",1-Sep-14,Platinum,Bills,F,67932']

# %%
import datetime
cc = cc.map(lambda x : x.split(',')) 
cc.take(10)
# Out:
# [['"Delhi', ' India"', '29-Oct-14', 'Gold', 'Bills', 'F', '82475'],
#  ['"Greater Mumbai',
#   ' India"',
#   '22-Aug-14',
#   'Platinum',
#   'Bills',
#   'F',
#   '32555'],
#  ['"Bengaluru', ' India"', '27-Aug-14', 'Silver', 'Bills', 'F', '101738'],
#  ['"Greater Mumbai',
#   ' India"',
#   '12-Apr-14',
#   'Signature',
#   'Bills',
#   'F',
#   '123424'],
#  ['"Bengaluru', ' India"', '5-May-15', 'Gold', 'Bills', 'F', '171574'],
#  ['"Delhi', ' India"', '8-Sep-14', 'Silver', 'Bills', 'F', '100036'],
#  ['"Delhi', ' India"', '24-Feb-15', 'Gold', 'Bills', 'F', '143250'],
#  ['"Greater Mumbai',
#   ' India"',
#   '26-Jun-14',
#   'Platinum',
#   'Bills',
#   'F',
#   '150980'],
#  ['"Delhi', ' India"', '28-Mar-14', 'Silver', 'Bills', 'F', '192247'],
#  ['"Delhi', ' India"', '1-Sep-14', 'Platinum', 'Bills', 'F', '67932']]

# %%
cc = cc.map(lambda x : (x[0][1:], x[1][1:-1], datetime.datetime.strptime(x[2], '%d-%b-%y').date(), x[3], x[4], x[5], float(x[6])))
print (cc.collect())
# Out:
# [('Delhi', 'India', datetime.date(2014, 10, 29), 'Gold', 'Bills', 'F', 82475.0), ('Greater Mumbai', 'India', datetime.date(2014, 8, 22), 'Platinum', 'Bills', 'F', 32555.0), ('Bengaluru', 'India', datetime.date(2014, 8, 27), 'Silver', 'Bills', 'F', 101738.0), ('Greater Mumbai', 'India', datetime.date(2014, 4, 12), 'Signature', 'Bills', 'F', 123424.0), ('Bengaluru', 'India', datetime.date(2015, 5, 5), 'Gold', 'Bills', 'F', 171574.0), ('Delhi', 'India', datetime.date(2014, 9, 8), 'Silver', 'Bills', 'F', 100036.0), ('Delhi', 'India', datetime.date(2015, 2, 24), 'Gold', 'Bills', 'F', 143250.0), ('Greater Mumbai', 'India', datetime.date(2014, 6, 26), 'Platinum', 'Bills', 'F', 150980.0), ('Delhi', 'India', datetime.date(2014, 3, 28), 'Silver', 'Bills', 'F', 192247.0), ('Delhi', 'India', datetime.date(2014, 9, 1), 'Platinum', 'Bills', 'F', 67932.0), ('Delhi', 'India', datetime.date(2014, 6, 22), 'Platinum', 'Bills', 'F', 280061.0), ('Greater Mumbai', 'India', datetime.date(2013, 12, 7), 'Signature', 'Bills', 'F', 278036.0), ('Greater Mumbai', 'India', datetime.date(2014, 8, 7), 'Gold', 'Bills', 'F', 19226.0), ('Delhi', 'India', datetime.date(2014, 4, 27), 'Signature', 'Bills', 'F', 254359.0), ('Greater Mumbai', 'India', datetime.date(2014, 8, 15), 'Signature', 'Bills', 'F', 302834.0), ('Greater Mumbai', 'India', datetime.date(2014, 11, 28), 'Platinum', 'Bills', 'F', 647116.0), ('Greater Mumbai', 'India', datetime.date(2014, 6, 14), 'Signature', 'Bills', 'F', 421878.0), ('Greater Mumbai', 'India', datetime.date(2015, 3, 30), 'Gold', 'Bills', 'F', 986379.0), ('Greater Mumbai', 'India', datetime.date(2014, 3, 15), 'Platinum', 'Bills', 'F', 213047.0), ('Greater Mumbai', 'India', datetime.date(2013, 11, 9), 'Platinum', 'Bills', 'F', 735566.0), ('Delhi', 'India', datetime.date(2014, 4, 4), 'Signature', 'Bills', 'F', 366102.0), ('Delhi', 'India', datetime.date(2014, 7, 1), 'Signature', 'Bills', 'F', 809623.0), ('Greater Mumbai', 'India', datetime.date(2015, 3, 27), 'Silver', 'Bills', 'F', 467014.0), ('Ahmedabad', 'India', datetime.date(2013, 10, 11), 'Gold', 'Bills', 'F', 668568.0), ('Ahmedabad', 'India', datetime.date(2014, 3, 26), 'Gold', 'Bills', 'F', 339112.0), ('Delhi', 'India', datetime.date(2014, 9, 27), 'Silver', 'Bills', 'F', 622170.0), ('Bengaluru', 'India', datetime.date(2014, 3, 23), 'Platinum', 'Bills', 'F', 434427.0), ('Greater Mumbai', 'India', datetime.date(2014, 5, 17), 'Signature', 'Bills', 'F', 655846.0), ('Bengaluru', 'India', datetime.date(2015, 1, 18), 'Platinum', 'Bills', 'F', 987935.0), ('Delhi', 'India', datetime.date(2015, 4, 18), 'Gold', 'Bills', 'F', 702774.0), ('Bengaluru', 'India', datetime.date(2014, 7, 31), 'Signature', 'Bills', 'F', 225392.0), ('Greater Mumbai', 'India', datetime.date(2015, 2, 11), 'Gold', 'Bills', 'F', 296573.0), ('Ahmedabad', 'India', datetime.date(2013, 11, 24), 'Platinum', 'Bills', 'F', 227702.0), ('Ahmedabad', 'India', datetime.date(2014, 11, 8), 'Gold', 'Bills', 'F', 864090.0), ('Ahmedabad', 'India', datetime.date(2014, 9, 6), 'Signature', 'Bills', 'F', 440605.0), ('Ahmedabad', 'India', datetime.date(2015, 3, 24), 'Platinum', 'Bills', 'F', 954660.0), ('Ahmedabad', 'India', datetime.date(2014, 1, 1), 'Signature', 'Bills', 'F', 255577.0), ('Ahmedabad', 'India', datetime.date(2014, 7, 12), 'Silver', 'Bills', 'F', 337352.0), ('Ahmedabad', 'India', datetime.date(2014, 2, 4), 'Platinum', 'Bills', 'F', 660244.0), ('Delhi', 'India', datetime.date(2015, 2, 3), 'Silver', 'Bills', 'F', 401351.0), ('Delhi', 'India', datetime.date(2013, 10, 27), 'Platinum', 'Bills', 'F', 678842.0), ('Delhi', 'India', datetime.date(2014, 5, 11), 'Gold', 'Bills', 'F', 478861.0), ('Bengaluru', 'India', datetime.date(2014, 11, 10), 'Platinum', 'Bills', 'F', 804938.0), ('Delhi', 'India', datetime.date(2015, 1, 30), 'Silver', 'Bills', 'F', 888341.0), ('Bengaluru', 'India', datetime.date(2014, 4, 19), 'Platinum', 'Bills', 'F', 262414.0), ('Bengaluru', 'India', datetime.date(2014, 9, 8), 'Gold', 'Bills', 'F', 249353.0), ('A ...

# %% [markdown]
# Turn the RDD into a DataFrame

# %%
df = spark.createDataFrame(cc)
df.show()
# Out:
# +--------------+-----+----------+---------+-----+---+--------+
# |            _1|   _2|        _3|       _4|   _5| _6|      _7|
# +--------------+-----+----------+---------+-----+---+--------+
# |         Delhi|India|2014-10-29|     Gold|Bills|  F| 82475.0|
# |Greater Mumbai|India|2014-08-22| Platinum|Bills|  F| 32555.0|
# |     Bengaluru|India|2014-08-27|   Silver|Bills|  F|101738.0|
# |Greater Mumbai|India|2014-04-12|Signature|Bills|  F|123424.0|
# |     Bengaluru|India|2015-05-05|     Gold|Bills|  F|171574.0|
# |         Delhi|India|2014-09-08|   Silver|Bills|  F|100036.0|
# |         Delhi|India|2015-02-24|     Gold|Bills|  F|143250.0|
# |Greater Mumbai|India|2014-06-26| Platinum|Bills|  F|150980.0|
# |         Delhi|India|2014-03-28|   Silver|Bills|  F|192247.0|
# |         Delhi|India|2014-09-01| Platinum|Bills|  F| 67932.0|
# |         Delhi|India|2014-06-22| Platinum|Bills|  F|280061.0|
# |Greater Mumbai|India|2013-12-07|Signature|Bills|  F|278036.0|
# |Greater Mumbai|India|2014-08-07|     Gold|Bills|  F| 19226.0|
# |         Delhi|India|2014-04-27|Signature|Bills|  F|254359.0|
# |Greater Mumbai|India|2014-08-15|Signature|Bills|  F|302834.0|
# |Greater Mumbai|India|2014-11-28| Platinum|Bills|  F|647116.0|
# |Greater Mumbai|India|2014-06-14|Signature|Bills|  F|421878.0|
# |Greater Mumbai|India|2015-03-30|     Gold|Bills|  F|986379.0|
# |Greater Mumbai|India|2014-03-15| Platinum|Bills|  F|213047.0|
# |Greater Mumbai|India|2013-11-09| Platinum|Bills|  F|735566.0|
# +--------------+-----+----------+---------+-----+---+--------+
# only showing top 20 rows

# %% [markdown]
# The built in toDF method does the same thing

# %%
df = cc.toDF()
df.show()
print(df)
# Out:
# +--------------+-----+----------+---------+-----+---+--------+
# |            _1|   _2|        _3|       _4|   _5| _6|      _7|
# +--------------+-----+----------+---------+-----+---+--------+
# |         Delhi|India|2014-10-29|     Gold|Bills|  F| 82475.0|
# |Greater Mumbai|India|2014-08-22| Platinum|Bills|  F| 32555.0|
# |     Bengaluru|India|2014-08-27|   Silver|Bills|  F|101738.0|
# |Greater Mumbai|India|2014-04-12|Signature|Bills|  F|123424.0|
# |     Bengaluru|India|2015-05-05|     Gold|Bills|  F|171574.0|
# |         Delhi|India|2014-09-08|   Silver|Bills|  F|100036.0|
# |         Delhi|India|2015-02-24|     Gold|Bills|  F|143250.0|
# |Greater Mumbai|India|2014-06-26| Platinum|Bills|  F|150980.0|
# |         Delhi|India|2014-03-28|   Silver|Bills|  F|192247.0|
# |         Delhi|India|2014-09-01| Platinum|Bills|  F| 67932.0|
# |         Delhi|India|2014-06-22| Platinum|Bills|  F|280061.0|
# |Greater Mumbai|India|2013-12-07|Signature|Bills|  F|278036.0|
# |Greater Mumbai|India|2014-08-07|     Gold|Bills|  F| 19226.0|
# |         Delhi|India|2014-04-27|Signature|Bills|  F|254359.0|
# |Greater Mumbai|India|2014-08-15|Signature|Bills|  F|302834.0|
# |Greater Mumbai|India|2014-11-28| Platinum|Bills|  F|647116.0|
# |Greater Mumbai|India|2014-06-14|Signature|Bills|  F|421878.0|
# |Greater Mumbai|India|2015-03-30|     Gold|Bills|  F|986379.0|
# |Greater Mumbai|India|2014-03-15| Platinum|Bills|  F|213047.0|
# |Greater Mumbai|India|2013-11-09| Platinum|Bills|  F|735566.0|
# +--------------+-----+----------+---------+-----+---+--------+
# only showing top 20 rows
#
# DataFrame[_1: string, _2: string, _3: date, _4: string, _5: string, _6: string, _7: double]

# %%
df = cc.toDF(['City', 'Country', 'Date', 'CardType', 'TranType', 'Gender', 'Amount'])
df.show()
# Out:
# +--------------+-------+----------+---------+--------+------+--------+
# |          City|Country|      Date| CardType|TranType|Gender|  Amount|
# +--------------+-------+----------+---------+--------+------+--------+
# |         Delhi|  India|2014-10-29|     Gold|   Bills|     F| 82475.0|
# |Greater Mumbai|  India|2014-08-22| Platinum|   Bills|     F| 32555.0|
# |     Bengaluru|  India|2014-08-27|   Silver|   Bills|     F|101738.0|
# |Greater Mumbai|  India|2014-04-12|Signature|   Bills|     F|123424.0|
# |     Bengaluru|  India|2015-05-05|     Gold|   Bills|     F|171574.0|
# |         Delhi|  India|2014-09-08|   Silver|   Bills|     F|100036.0|
# |         Delhi|  India|2015-02-24|     Gold|   Bills|     F|143250.0|
# |Greater Mumbai|  India|2014-06-26| Platinum|   Bills|     F|150980.0|
# |         Delhi|  India|2014-03-28|   Silver|   Bills|     F|192247.0|
# |         Delhi|  India|2014-09-01| Platinum|   Bills|     F| 67932.0|
# |         Delhi|  India|2014-06-22| Platinum|   Bills|     F|280061.0|
# |Greater Mumbai|  India|2013-12-07|Signature|   Bills|     F|278036.0|
# |Greater Mumbai|  India|2014-08-07|     Gold|   Bills|     F| 19226.0|
# |         Delhi|  India|2014-04-27|Signature|   Bills|     F|254359.0|
# |Greater Mumbai|  India|2014-08-15|Signature|   Bills|     F|302834.0|
# |Greater Mumbai|  India|2014-11-28| Platinum|   Bills|     F|647116.0|
# |Greater Mumbai|  India|2014-06-14|Signature|   Bills|     F|421878.0|
# |Greater Mumbai|  India|2015-03-30|     Gold|   Bills|     F|986379.0|
# |Greater Mumbai|  India|2014-03-15| Platinum|   Bills|     F|213047.0|
# |Greater Mumbai|  India|2013-11-09| Platinum|   Bills|     F|735566.0|
# +--------------+-------+----------+---------+--------+------+--------+
# only showing top 20 rows

# %%
df = cc.toDF('City: string, Country: string, Date: date, CardType: string, TranType: string, Gender: string, Amount: double')
df.show()
print(df)
# Out:
# +--------------+-------+----------+---------+--------+------+--------+
# |          City|Country|      Date| CardType|TranType|Gender|  Amount|
# +--------------+-------+----------+---------+--------+------+--------+
# |         Delhi|  India|2014-10-29|     Gold|   Bills|     F| 82475.0|
# |Greater Mumbai|  India|2014-08-22| Platinum|   Bills|     F| 32555.0|
# |     Bengaluru|  India|2014-08-27|   Silver|   Bills|     F|101738.0|
# |Greater Mumbai|  India|2014-04-12|Signature|   Bills|     F|123424.0|
# |     Bengaluru|  India|2015-05-05|     Gold|   Bills|     F|171574.0|
# |         Delhi|  India|2014-09-08|   Silver|   Bills|     F|100036.0|
# |         Delhi|  India|2015-02-24|     Gold|   Bills|     F|143250.0|
# |Greater Mumbai|  India|2014-06-26| Platinum|   Bills|     F|150980.0|
# |         Delhi|  India|2014-03-28|   Silver|   Bills|     F|192247.0|
# |         Delhi|  India|2014-09-01| Platinum|   Bills|     F| 67932.0|
# |         Delhi|  India|2014-06-22| Platinum|   Bills|     F|280061.0|
# |Greater Mumbai|  India|2013-12-07|Signature|   Bills|     F|278036.0|
# |Greater Mumbai|  India|2014-08-07|     Gold|   Bills|     F| 19226.0|
# |         Delhi|  India|2014-04-27|Signature|   Bills|     F|254359.0|
# |Greater Mumbai|  India|2014-08-15|Signature|   Bills|     F|302834.0|
# |Greater Mumbai|  India|2014-11-28| Platinum|   Bills|     F|647116.0|
# |Greater Mumbai|  India|2014-06-14|Signature|   Bills|     F|421878.0|
# |Greater Mumbai|  India|2015-03-30|     Gold|   Bills|     F|986379.0|
# |Greater Mumbai|  India|2014-03-15| Platinum|   Bills|     F|213047.0|
# |Greater Mumbai|  India|2013-11-09| Platinum|   Bills|     F|735566.0|
# +--------------+-------+----------+---------+--------+------+--------+
# only showing top 20 rows
#
# DataFrame[City: string, Country: string, Date: date, CardType: string, TranType: string, Gender: string, Amount: double]

# %% [markdown]
# **LAB:** Use the regions and territories RDDs from the previous lab and convert them into  dataframes with meaningful schemas.

# %% [markdown]
# Convert a DataFrame into a JSON string

# %%
print (df.toJSON().take(10))
# Out:
# ['{"City":"Delhi","Country":"India","Date":"2014-10-29","CardType":"Gold","TranType":"Bills","Gender":"F","Amount":82475.0}', '{"City":"Greater Mumbai","Country":"India","Date":"2014-08-22","CardType":"Platinum","TranType":"Bills","Gender":"F","Amount":32555.0}', '{"City":"Bengaluru","Country":"India","Date":"2014-08-27","CardType":"Silver","TranType":"Bills","Gender":"F","Amount":101738.0}', '{"City":"Greater Mumbai","Country":"India","Date":"2014-04-12","CardType":"Signature","TranType":"Bills","Gender":"F","Amount":123424.0}', '{"City":"Bengaluru","Country":"India","Date":"2015-05-05","CardType":"Gold","TranType":"Bills","Gender":"F","Amount":171574.0}', '{"City":"Delhi","Country":"India","Date":"2014-09-08","CardType":"Silver","TranType":"Bills","Gender":"F","Amount":100036.0}', '{"City":"Delhi","Country":"India","Date":"2015-02-24","CardType":"Gold","TranType":"Bills","Gender":"F","Amount":143250.0}', '{"City":"Greater Mumbai","Country":"India","Date":"2014-06-26","CardType":"Platinum","TranType":"Bills","Gender":"F","Amount":150980.0}', '{"City":"Delhi","Country":"India","Date":"2014-03-28","CardType":"Silver","TranType":"Bills","Gender":"F","Amount":192247.0}', '{"City":"Delhi","Country":"India","Date":"2014-09-01","CardType":"Platinum","TranType":"Bills","Gender":"F","Amount":67932.0}']

# %%
df.printSchema()
print (df.columns, df.count())
# Out:
# root
#  |-- City: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Date: date (nullable = true)
#  |-- CardType: string (nullable = true)
#  |-- TranType: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Amount: double (nullable = true)
#
# ['City', 'Country', 'Date', 'CardType', 'TranType', 'Gender', 'Amount'] 26052

# %% [markdown]
# Choose particular columns from a DataFrame

# %%
df.select('City', 'Country', 'Amount').show(10)
# Out:
# +--------------+-------+--------+
# |          City|Country|  Amount|
# +--------------+-------+--------+
# |         Delhi|  India| 82475.0|
# |Greater Mumbai|  India| 32555.0|
# |     Bengaluru|  India|101738.0|
# |Greater Mumbai|  India|123424.0|
# |     Bengaluru|  India|171574.0|
# |         Delhi|  India|100036.0|
# |         Delhi|  India|143250.0|
# |Greater Mumbai|  India|150980.0|
# |         Delhi|  India|192247.0|
# |         Delhi|  India| 67932.0|
# +--------------+-------+--------+
# only showing top 10 rows

# %%
df.select('City', 'Country').distinct().show()
# Out:
# +------------+-------+
# |        City|Country|
# +------------+-------+
# |      Bhabua|  India|
# |      Rajgir|  India|
# |    Mahidpur|  India|
# |   Brahmapur|  India|
# |     Udaipur|  India|
# |    Sunabeda|  India|
# |     Kurnool|  India|
# | Kodungallur|  India|
# |    Surapura|  India|
# |    Kashipur|  India|
# |       Mansa|  India|
# |Wadgaon Road|  India|
# |   Lingsugur|  India|
# |  Sultanganj|  India|
# | Udaipurwati|  India|
# | Nanjikottai|  India|
# |       Buxar|  India|
# |       Raver|  India|
# |  Nedumangad|  India|
# | Tilda Newra|  India|
# +------------+-------+
# only showing top 20 rows

# %% [markdown]
# Sort a DataFrame. The sort and orderBy methods are different aliases for the exact same method

# %%
df.sort(df.Amount).show()
df.sort(df.Amount, ascending = False).show()
df.select('City', 'Amount').orderBy(df.City).show()
# Out:
# +--------------+-------+----------+---------+-------------+------+------+
# |          City|Country|      Date| CardType|     TranType|Gender|Amount|
# +--------------+-------+----------+---------+-------------+------+------+
# |         Delhi|  India|2014-05-02| Platinum|      Grocery|     F|1005.0|
# |   Murshidabad|  India|2014-06-12|   Silver|         Food|     M|1018.0|
# |     Ahmedabad|  India|2015-01-19|Signature|      Grocery|     F|1024.0|
# |       Lucknow|  India|2014-03-16|Signature|        Bills|     F|1026.0|
# |     Ahmedabad|  India|2015-02-23|   Silver|         Food|     F|1028.0|
# |     Ahmedabad|  India|2015-02-12|     Gold|         Fuel|     F|1038.0|
# |Greater Mumbai|  India|2014-04-30|     Gold|        Bills|     F|1056.0|
# |         Delhi|  India|2014-12-19|     Gold|Entertainment|     F|1061.0|
# |       Chennai|  India|2014-07-23|     Gold|         Food|     F|1066.0|
# |     Hyderabad|  India|2013-11-13|     Gold|       Travel|     F|1070.0|
# |     Bengaluru|  India|2013-12-02|   Silver|Entertainment|     F|1074.0|
# |     Bengaluru|  India|2014-01-19|   Silver|        Bills|     F|1078.0|
# |Greater Mumbai|  India|2014-09-06|     Gold|      Grocery|     M|1099.0|
# |     Bengaluru|  India|2014-05-17|     Gold|        Bills|     M|1103.0|
# |        Etawah|  India|2014-06-02|   Silver|      Grocery|     F|1104.0|
# |         Delhi|  India|2014-02-23|     Gold|      Grocery|     F|1105.0|
# |        Bhabua|  India|2014-08-02| Platinum|      Grocery|     F|1123.0|
# |       Lucknow|  India|2014-01-07| Platinum|Entertainment|     F|1133.0|
# |     Bengaluru|  India|2014-12-04|   Silver|      Grocery|     M|1139.0|
# |     Bengaluru|  India|2014-10-19|   Silver|         Fuel|     M|1161.0|
# +--------------+-------+----------+---------+-------------+------+------+
# only showing top 20 rows
#
# +--------------+-------+----------+---------+--------+------+--------+
# |          City|Country|      Date| CardType|TranType|Gender|  Amount|
# +--------------+-------+----------+---------+--------+------+--------+
# |Greater Mumbai|  India|2014-10-14| Platinum|   Bills|     F|998077.0|
# |         Delhi|  India|2013-10-27|     Gold|   Bills|     F|996754.0|
# |     Ahmedabad|  India|2015-04-17|     Gold|   Bills|     F|996291.0|
# |     Ahmedabad|  India|2014-08-27| Platinum|   Bills|     F|995634.0|
# |         Delhi|  India|2014-06-07|Signature|   Bills|     F|994537.0|
# |Greater Mumbai|  India|2014-09-06|Signature|   Bills|     F|994184.0|
# |Greater Mumbai|  India|2014-03-22|     Gold|   Bills|     F|991685.0|
# |Greater Mumbai|  India|2013-10-04|     Gold|   Bills|     F|990700.0|
# |     Bengaluru|  India|2015-01-18| Platinum|   Bills|     F|987935.0|
# |Greater Mumbai|  India|2015-03-30|     Gold|   Bills|     F|986379.0|
# |     Bengaluru|  India|2014-03-06|Signature|   Bills|     F|984466.0|
# |     Bengaluru|  India|2015-01-19| Platinum|   Bills|     F|983839.0|
# |         Delhi|  India|2015-02-15|Signature|   Bills|     F|981404.0|
# |     Ahmedabad|  India|2015-03-25|     Gold|   Bills|     F|980146.0|
# |Greater Mumbai|  India|2014-06-15|     Gold|   Bills|     F|978989.0|
# |Greater Mumbai|  India|2013-10-22|Signature|   Bills|     F|978301.0|
# |     Bengaluru|  India|2015-05-19|Signature|   Bills|     F|977951.0|
# |         Delhi|  India|2014-04-18|     Gold|   Bills|     F|974384.0|
# |         Delhi|  India|2014-10-18|     Gold|   Bills|     F|973519.0|
# |     Bengaluru|  India|2013-10-13|Signature|   Bills|     F|973026.0|
# +--------------+-------+----------+---------+--------+------+--------+
# only showing top 20 rows
#
# +---------+--------+
# |     City|  Amount|
# +---------+--------+
# | Achalpur|173336.0|
# | Achalpur|178612.0|
# | Achalpur| 55347.0|
# | Achalpur|216180.0|
# | Achalpur|201032.0|
# | Achalpur|138246.0|
# | Achalpur|209805.0|
# | Achalpur|241504.0|
# | Achalpur|192579.0|
# | Adilabad|278085.0|
# | Adilabad|189159.0|
# | Adilabad|278459.0|
# | Adilabad|108313.0|
# | Adilabad|258225.0|
# | Adilabad| 49020.0|
# | Adilabad| 80193.0|
# | Adilabad|178349.0|
# | Adilabad|227325.0|
# | Adilabad|122336.0|
# |Adityapur| 50289.0|
# +---------+--------+
# only showing top 20 rows

# %% [markdown]
# Create a new DataFrame with a new calculated column added

# %%
df2 = df.withColumn('Discount', df.Amount * .03)
df2.show()
# Out:
# +--------------+-------+----------+---------+--------+------+--------+------------------+
# |          City|Country|      Date| CardType|TranType|Gender|  Amount|          Discount|
# +--------------+-------+----------+---------+--------+------+--------+------------------+
# |         Delhi|  India|2014-10-29|     Gold|   Bills|     F| 82475.0|           2474.25|
# |Greater Mumbai|  India|2014-08-22| Platinum|   Bills|     F| 32555.0|            976.65|
# |     Bengaluru|  India|2014-08-27|   Silver|   Bills|     F|101738.0|           3052.14|
# |Greater Mumbai|  India|2014-04-12|Signature|   Bills|     F|123424.0|           3702.72|
# |     Bengaluru|  India|2015-05-05|     Gold|   Bills|     F|171574.0|           5147.22|
# |         Delhi|  India|2014-09-08|   Silver|   Bills|     F|100036.0|           3001.08|
# |         Delhi|  India|2015-02-24|     Gold|   Bills|     F|143250.0|            4297.5|
# |Greater Mumbai|  India|2014-06-26| Platinum|   Bills|     F|150980.0|            4529.4|
# |         Delhi|  India|2014-03-28|   Silver|   Bills|     F|192247.0|           5767.41|
# |         Delhi|  India|2014-09-01| Platinum|   Bills|     F| 67932.0|           2037.96|
# |         Delhi|  India|2014-06-22| Platinum|   Bills|     F|280061.0|           8401.83|
# |Greater Mumbai|  India|2013-12-07|Signature|   Bills|     F|278036.0|           8341.08|
# |Greater Mumbai|  India|2014-08-07|     Gold|   Bills|     F| 19226.0|            576.78|
# |         Delhi|  India|2014-04-27|Signature|   Bills|     F|254359.0|7630.7699999999995|
# |Greater Mumbai|  India|2014-08-15|Signature|   Bills|     F|302834.0|           9085.02|
# |Greater Mumbai|  India|2014-11-28| Platinum|   Bills|     F|647116.0|          19413.48|
# |Greater Mumbai|  India|2014-06-14|Signature|   Bills|     F|421878.0|          12656.34|
# |Greater Mumbai|  India|2015-03-30|     Gold|   Bills|     F|986379.0|          29591.37|
# |Greater Mumbai|  India|2014-03-15| Platinum|   Bills|     F|213047.0|           6391.41|
# |Greater Mumbai|  India|2013-11-09| Platinum|   Bills|     F|735566.0|          22066.98|
# +--------------+-------+----------+---------+--------+------+--------+------------------+
# only showing top 20 rows

# %% [markdown]
# Remove an unwanted column from a DataFrame

# %%
df3 = df2.drop(df2.Country)
df3.show()
# Out:
# +--------------+----------+---------+--------+------+--------+------------------+
# |          City|      Date| CardType|TranType|Gender|  Amount|          Discount|
# +--------------+----------+---------+--------+------+--------+------------------+
# |         Delhi|2014-10-29|     Gold|   Bills|     F| 82475.0|           2474.25|
# |Greater Mumbai|2014-08-22| Platinum|   Bills|     F| 32555.0|            976.65|
# |     Bengaluru|2014-08-27|   Silver|   Bills|     F|101738.0|           3052.14|
# |Greater Mumbai|2014-04-12|Signature|   Bills|     F|123424.0|           3702.72|
# |     Bengaluru|2015-05-05|     Gold|   Bills|     F|171574.0|           5147.22|
# |         Delhi|2014-09-08|   Silver|   Bills|     F|100036.0|           3001.08|
# |         Delhi|2015-02-24|     Gold|   Bills|     F|143250.0|            4297.5|
# |Greater Mumbai|2014-06-26| Platinum|   Bills|     F|150980.0|            4529.4|
# |         Delhi|2014-03-28|   Silver|   Bills|     F|192247.0|           5767.41|
# |         Delhi|2014-09-01| Platinum|   Bills|     F| 67932.0|           2037.96|
# |         Delhi|2014-06-22| Platinum|   Bills|     F|280061.0|           8401.83|
# |Greater Mumbai|2013-12-07|Signature|   Bills|     F|278036.0|           8341.08|
# |Greater Mumbai|2014-08-07|     Gold|   Bills|     F| 19226.0|            576.78|
# |         Delhi|2014-04-27|Signature|   Bills|     F|254359.0|7630.7699999999995|
# |Greater Mumbai|2014-08-15|Signature|   Bills|     F|302834.0|           9085.02|
# |Greater Mumbai|2014-11-28| Platinum|   Bills|     F|647116.0|          19413.48|
# |Greater Mumbai|2014-06-14|Signature|   Bills|     F|421878.0|          12656.34|
# |Greater Mumbai|2015-03-30|     Gold|   Bills|     F|986379.0|          29591.37|
# |Greater Mumbai|2014-03-15| Platinum|   Bills|     F|213047.0|           6391.41|
# |Greater Mumbai|2013-11-09| Platinum|   Bills|     F|735566.0|          22066.98|
# +--------------+----------+---------+--------+------+--------+------------------+
# only showing top 20 rows

# %% [markdown]
# The filter and where methods can both be used and have alternative ways to represent the condition

# %%
df3.filter(df3.Amount < 4000).show()
print(df3.filter('Amount < 4000').count())
print(df3.where('Amount < 4000').count())
print(df3.where(df3.Amount < 4000).count())

print (df3.where((df3.Amount > 3000) & (df3.Amount < 4000)).count())
print (df3.where('Amount > 3000 and Amount < 4000').count())
# Out:
# +--------------+----------+---------+-------------+------+------+------------------+
# |          City|      Date| CardType|     TranType|Gender|Amount|          Discount|
# +--------------+----------+---------+-------------+------+------+------------------+
# |     Bengaluru|2015-02-05| Platinum|        Bills|     F|3427.0|            102.81|
# |Greater Mumbai|2015-04-27|Signature|        Bills|     F|2138.0|             64.14|
# |     Bengaluru|2013-10-18|Signature|         Food|     F|2397.0|             71.91|
# |     Bengaluru|2015-02-07|   Silver|         Fuel|     F|2686.0|             80.58|
# |         Delhi|2014-01-23|   Silver|         Food|     F|1400.0|              42.0|
# |     Ahmedabad|2013-10-31|   Silver|         Fuel|     F|2586.0|             77.58|
# |     Bengaluru|2014-05-08|   Silver|        Bills|     F|2741.0|             82.23|
# |     Bengaluru|2014-01-10|   Silver|         Food|     F|3421.0|            102.63|
# |     Bengaluru|2015-04-29| Platinum|         Food|     F|3621.0|            108.63|
# |         Delhi|2015-03-20|   Silver|         Food|     F|1709.0|51.269999999999996|
# |Greater Mumbai|2015-05-05|Signature|         Food|     F|1448.0|             43.44|
# |     Bengaluru|2014-05-26| Platinum|         Food|     M|3445.0|            103.35|
# |     Ahmedabad|2014-02-13|Signature|         Food|     F|3139.0|             94.17|
# |Greater Mumbai|2015-03-20|   Silver|        Bills|     F|2543.0| 76.28999999999999|
# |Greater Mumbai|2014-10-29|     Gold|         Fuel|     M|1904.0|             57.12|
# |Greater Mumbai|2014-07-15| Platinum|Entertainment|     F|3278.0|             98.34|
# |Greater Mumbai|2014-11-13|     Gold|         Fuel|     F|3800.0|             114.0|
# |         Delhi|2013-12-02|Signature|         Fuel|     M|2474.0|             74.22|
# |     Ahmedabad|2014-10-13|     Gold|         Fuel|     F|1925.0|             57.75|
# |Greater Mumbai|2015-02-24|   Silver|         Fuel|     F|1845.0|             55.35|
# +--------------+----------+---------+-------------+------+------+------------------+
# only showing top 20 rows
#
# 277
# 277
# 277
# 91
# 91

# %% [markdown]
# Load a CSV file directly into a DataFrame using alternate syntaxes

# %% [markdown]
# **LAB:** Using the df3 dataframe answer the following questions:
# How many Platinum card purchases where there with a discount above $100
# Find the ten biggest discount amounts earned by women and show just the purchase amount, discount and date

# %% [markdown]
# JOINs work as expected

# %%
tab1 = sc.parallelize([(1, 'Alpha'), (2, 'Beta'), (3, 'Delta')]).toDF('ID:int, code:string')
tab2 = sc.parallelize([(100, 'One', 1), (101, 'Two', 2), (102, 'Three', 1), (103, 'Four', 4)]).toDF('ID:int, name:string, parentID:int')
tab1.join(tab2, tab1.ID == tab2.parentID).show()
tab1.join(tab2, tab1.ID == tab2.parentID, 'left').show()
tab1.join(tab2, tab1.ID == tab2.parentID, 'right').show()
tab1.join(tab2, tab1.ID == tab2.parentID, 'full').show()
# Out:
# +---+-----+---+-----+--------+
# | ID| code| ID| name|parentID|
# +---+-----+---+-----+--------+
# |  1|Alpha|100|  One|       1|
# |  1|Alpha|102|Three|       1|
# |  2| Beta|101|  Two|       2|
# +---+-----+---+-----+--------+
#
# +---+-----+----+-----+--------+
# | ID| code|  ID| name|parentID|
# +---+-----+----+-----+--------+
# |  1|Alpha| 100|  One|       1|
# |  1|Alpha| 102|Three|       1|
# |  3|Delta|null| null|    null|
# |  2| Beta| 101|  Two|       2|
# +---+-----+----+-----+--------+
#
# +----+-----+---+-----+--------+
# |  ID| code| ID| name|parentID|
# +----+-----+---+-----+--------+
# |   1|Alpha|100|  One|       1|
# |   1|Alpha|102|Three|       1|
# |null| null|103| Four|       4|
# |   2| Beta|101|  Two|       2|
# +----+-----+---+-----+--------+
#
# +----+-----+----+-----+--------+
# |  ID| code|  ID| name|parentID|
# +----+-----+----+-----+--------+
# |   1|Alpha| 100|  One|       1|
# |   1|Alpha| 102|Three|       1|
# |   3|Delta|null| null|    null|
# |null| null| 103| Four|       4|
# |   2| Beta| 101|  Two|       2|
# +----+-----+----+-----+--------+

# %% [markdown]
# Examples of aggregate functions

# %%
tab3 = sc.parallelize([(1, 10), (1, 20), (1, 30), (2, 40), (2,50)]).toDF('groupID:int, amount:int')
tab3.groupby('groupID').max().show()
tab3.groupby('groupID').sum().show()
x = tab3.groupby('groupID')
x.agg({'amount':'sum', 'amount':'max'}).show()
from pyspark.sql import functions as F
x.agg(F.sum('amount'), F.max('amount')).show()
# Out:
# +-------+-----------+
# |groupID|max(amount)|
# +-------+-----------+
# |      1|         30|
# |      2|         50|
# +-------+-----------+
#
# +-------+-----------+-----------+
# |groupID|sum(amount)|max(amount)|
# +-------+-----------+-----------+
# |      1|         60|         30|
# |      2|         90|         50|
# +-------+-----------+-----------+

# %% [markdown]
# Examples of reading a CSV directly into a dataframe

# %%
filename = '/home/student/ROI/SparkProgram/datasets/finance/CreditCard.csv'
df4 = spark.read.load(filename, format = 'csv', sep = ',', inferSchema = True, header = True)
df4.printSchema()

# %%
df4 = spark.read.format('csv').option('header','true').option('inferSchema','true').load(filename)
df4.printSchema()

# %%
df4 = spark.read.csv(filename, header = True, inferSchema = True)
df4.printSchema()

# %%
df4.show()

# %% [markdown]
# **LAB:** Read the Products file from the JSON folder and categories from ths CSVHeaders folder, then join them displaying just the product and category IDs and names, and sort by categoryID then productID.
#
# Hint. drop the ambiguous column after the join

# %% [markdown]
# Change the name of the City Column to CityCountry

# %%
cols = df4.columns
cols[0] = 'CityCountry'
df4 = df4.toDF(*cols)
df4.printSchema()

# %% [markdown]
# Apply a custom UDF to columns to separate the City and Country and convert the Date into a date datatype

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import *
from pyspark.sql.functions import to_date
import datetime

def city(x):
    return x[:x.find(',')]
def country(x):
    return x[x.find(',') + 1 :]

df5 = df4.withColumn('City', udf(city, StringType())(df4.CityCountry)) \
      .withColumn('Country', udf(country, StringType())(df4.CityCountry)) \
      .withColumn('Date', to_date(df4.Date, 'dd-MMM-yy')) \
      .drop(df4.CityCountry)
df5.show()

# %% [markdown]
# DataFrames can be written to a variety of file formats. Here we are writing it to JSON

# %%
df5.write.json('/home/student/Desktop/CreditCard.json')

# %% [markdown]
# Read a JSON file into a DataFrame, but note that we lose the datatypes

# %%
df6 = spark.read.json('/home/student/Desktop/CreditCard.json')
df6.printSchema()

# %% [markdown]
# Create a schema that can be used to import a file and directly name the columns and convert them to the desired data type

# %%
schema = StructType([
    StructField('Date', DateType()), 
    StructField('Card Type', StringType()),
    StructField('Exp Type', StringType()),
    StructField('Gender', StringType()),
    StructField('Amount', FloatType()),
    StructField('City', StringType()),
    StructField('Country', StringType())
])
df6 = spark.read.json('/home/student/Desktop/CreditCard.json', schema = schema)
df6.printSchema()

# %% [markdown]
# **HOMEWORK:**
#
# In the /home/student/ROI/SparkProgram/datasets/finance folder are two files:
# top50banks.tsv is tab separated
# countrycodes.json is a json file
# Using these two files, create an alphabetical list of countries and show the sum, min and max of their total assets and find the country with the most assets and what that amount is.
