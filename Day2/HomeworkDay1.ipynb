# %% [markdown]
# HOMEWORK:
# Find the total expenditure for each city in the CreditCard.csv

# %%
import sys
sys.path.append('/home/student/ROI/SparkProgram')
from initspark import *
sc, spark, conf = initspark()

# %%
cc = sc.textFile('/home/student/ROI/SparkProgram/datasets/finance/CreditCard.csv')
first = cc.first()
cc = cc.filter(lambda x : x != first)
cc.take(10)
# Out:
# ['"Delhi, India",29-Oct-14,Gold,Bills,F,82475',
#  '"Greater Mumbai, India",22-Aug-14,Platinum,Bills,F,32555',
#  '"Bengaluru, India",27-Aug-14,Silver,Bills,F,101738',
#  '"Greater Mumbai, India",12-Apr-14,Signature,Bills,F,123424',
#  '"Bengaluru, India",5-May-15,Gold,Bills,F,171574',
#  '"Delhi, India",8-Sep-14,Silver,Bills,F,100036',
#  '"Delhi, India",24-Feb-15,Gold,Bills,F,143250',
#  '"Greater Mumbai, India",26-Jun-14,Platinum,Bills,F,150980',
#  '"Delhi, India",28-Mar-14,Silver,Bills,F,192247',
#  '"Delhi, India",1-Sep-14,Platinum,Bills,F,67932']

# %%
cc = cc.map(lambda x : x.split(',')) 
cc.take(10)
# Out:
# [['"Delhi', ' India"', '29-Oct-14', 'Gold', 'Bills', 'F', '82475'],
#  ['"Greater Mumbai',
#   ' India"',
#   '22-Aug-14',
#   'Platinum',
#   'Bills',
#   'F',
#   '32555'],
#  ['"Bengaluru', ' India"', '27-Aug-14', 'Silver', 'Bills', 'F', '101738'],
#  ['"Greater Mumbai',
#   ' India"',
#   '12-Apr-14',
#   'Signature',
#   'Bills',
#   'F',
#   '123424'],
#  ['"Bengaluru', ' India"', '5-May-15', 'Gold', 'Bills', 'F', '171574'],
#  ['"Delhi', ' India"', '8-Sep-14', 'Silver', 'Bills', 'F', '100036'],
#  ['"Delhi', ' India"', '24-Feb-15', 'Gold', 'Bills', 'F', '143250'],
#  ['"Greater Mumbai',
#   ' India"',
#   '26-Jun-14',
#   'Platinum',
#   'Bills',
#   'F',
#   '150980'],
#  ['"Delhi', ' India"', '28-Mar-14', 'Silver', 'Bills', 'F', '192247'],
#  ['"Delhi', ' India"', '1-Sep-14', 'Platinum', 'Bills', 'F', '67932']]

# %%
cc = cc.map(lambda x : ((x[0][1:], x[1][1:-1]), (x[5], float(x[6]))))
print (cc.collect())
# Out:
# [(('Delhi', 'India'), ('F', 82475.0)), (('Greater Mumbai', 'India'), ('F', 32555.0)), (('Bengaluru', 'India'), ('F', 101738.0)), (('Greater Mumbai', 'India'), ('F', 123424.0)), (('Bengaluru', 'India'), ('F', 171574.0)), (('Delhi', 'India'), ('F', 100036.0)), (('Delhi', 'India'), ('F', 143250.0)), (('Greater Mumbai', 'India'), ('F', 150980.0)), (('Delhi', 'India'), ('F', 192247.0)), (('Delhi', 'India'), ('F', 67932.0)), (('Delhi', 'India'), ('F', 280061.0)), (('Greater Mumbai', 'India'), ('F', 278036.0)
mumbai', 'India'), ('F', 533762.0)), (('Greater Mumbai', 'India'), ('F', 829742.0)), (('Delhi', 'India'), ('F', 441527.0)), (('Delhi', 'India'), ('F', 550782.0)), (('Greater Mumbai', 'India'), ('F', 835872.0)), (('Ahmedabad', 'India'), ('F', 540497.0)), (('Greater Mumbai', 'India'), ('F', 525977.0)), (('Greater Mumbai', 'India'), ('F', 789393.0)), (('Greater Mumbai', 'India'), ('F', 689478.0)), (('Bengaluru', 'India'), ('F', 499079.0)), (('Ahmedabad', 'India'), ('F', 665107.0)), (('Greater Mumbai', 'India'), ('F', 998077.0)), (('Ahmedabad', 'India'), ('F', 934205.0)), (('Bengaluru', 'India'), ('F', 823426.0)), (('Ahmedabad', 'India'), ('F', 282910.0)), (('Bengaluru', 'India'), ('F', 418675.0)), (('Ahmedabad', 'India'), ('F', 804949.0)), (('Bengaluru', 'India'), ('F', 686601.0)), (('Greater Mumbai', 'India'), ('F', 561220.0)), (('Greater Mumbai', 'India'), ('F', 762534.0)), (('Bengaluru', 'India'), ('F', 327947.0)), (('Bengaluru', 'India'), ('F', 492986.0)), (('Delhi', 'India'), ('F', 3692 ...

# %%
ccf = cc.filter(lambda x : x[1][0] == 'F').map(lambda x : (x[0], x[1][1]))
ccg = ccf.reduceByKey(lambda x, y : x + y)
print (ccg.sortByKey().collect())
# Out:
# [(('Achalpur', 'India'), 860976.0), (('Adilabad', 'India'), 1164430.0), (('Adityapur', 'India'), 506773.0), (('Adoni', 'India'), 993742.0), (('Adoor', 'India'), 317437.0), (('Afzalpur', 'India'), 725277.0), (('Ahmedabad', 'India'), 319172275.0), (('Ahmednagar', 'India'), 140295.0), (('Aizawl', 'India'), 167467.0), (('Ajmer', 'India'), 414713.0), (('Akola', 'India'), 929075.0), (('Akot', 'India'), 359000.0), (('Alappuzha', 'India'), 771794.0), (('Aligarh', 'India'), 952360.0), (('Alipurduar', 'India'), 438232.0), (('Allahabad', 'India'), 337841.0), (('Alwar', 'India'), 285142.0), (('Amalapuram', 'India'), 335138.0), (('Amalner', 'India'), 727200.0), (('Ambejogai', 'India'), 997567.0), (('Ambikapur', 'India'), 687416.0), (('Amravati', 'India'), 993020.0), (('Amreli', 'India'), 502455.0), (('Amritsar', 'India'), 11130.0), (('Amroha', 'India'), 419149.0), (('Anakapalle', 'India'), 66672.0), (('Anand', 'India'), 242841.0), (('Anantnag', 'India'), 271565.0), (('Anjangaon', 'India'), 554210.0), (('Anjar', 'India'), 207628.0), (('Ankleshwar', 'India'), 152070.0), (('Arakkonam', 'India'), 387526.0), (('Arambagh', 'India'), 354052.0), (('Araria', 'India'), 760937.0), (('Arrah', 'India'), 178035.0), (('Arsikere', 'India'), 812375.0), (('Aruppukkottai', 'India'), 280721.0), (('Arvi', 'India'), 354720.0), (('Arwal', 'India'), 407504.0), (('Asansol', 'India'), 539265.0), (('Ashok Nagar', 'India'), 761165.0), (('Athni', 'India'), 462634.0), (('Aurangabad', 'India'), 474630.0), (('Azamgarh', 'India'), 30349.0), (('Bagaha', 'India'), 224207.0), (('Bahadurgarh', 'India'), 156494.0), (('Baharampur', 'India'), 102646.0), (('Bahraich', 'India'), 1243.0), (('Balaghat', 'India'), 133987.0), (('Balangir', 'India'), 172504.0), (('Baleshwar Town', 'India'), 220769.0), (('Ballari', 'India'), 684874.0), (('Balurghat', 'India'), 414702.0), (('Bankura', 'India'), 239944.0), (('Bapatla', 'India'), 153626.0), (('Baramula', 'India'), 858243.0), (('Barbil', 'India'), 913416.0), (('Bargarh', 'India'), 257942.0), (('Baripada Town', 'India'), 648647.0), (('Barnala', 'India'), 527156.0), (('Barpeta', 'India'), 387773.0), (('Batala', 'India'), 700580.0), (('Bathinda', 'India'), 930780.0), (('Begusarai', 'India'), 139827.0), (('Belagavi', 'India'), 632518.0), (('Bellampalle', 'India'), 718902.0), (('Bengaluru', 'India'), 331198446.0), (('Bhabua', 'India'), 460002.0), (('Bhadrachalam', 'India'), 238499.0), (('Bhadrak', 'India'), 636679.0), (('Bhagalpur', 'India'), 415201.0), (('Bhainsa', 'India'), 422272.0), (('Bharatpur', 'India'), 492675.0), (('Bharuch', 'India'), 830393.0), (('Bhatapara', 'India'), 214579.0), (('Bhavnagar', 'India'), 511492.0), (('Bhawanipatna', 'India'), 174346.0), (('Bheemunipatnam', 'India'), 789254.0), (('Bhilai Nagar', 'India'), 702588.0), (('Bhilwara', 'India'), 230043.0), (('Bhimavaram', 'India'), 200793.0), (('Bhiwandi', 'India'), 249111.0), (('Bhiwani', 'India'), 98053.0), (('Bhongir', 'India'), 487234.0), (('Bhuj', 'India'), 718604.0), (('Bikaner', 'India'), 892066.0), (('Bilaspur', 'India'), 374146.0), (('Bobbili', 'India'), 111078.0), (('Bodhan', 'India'), 641644.0), (('Bongaigaon City', 'India'), 487156.0), (('Brahmapur', 'India'), 202199.0), (('Buxar', 'India'), 832978.0), (('Byasanagar', 'India'), 643057.0), (('Chaibasa', 'India'), 383964.0), (('Chalakudy', 'India'), 340416.0), (('Chandausi', 'India'), 432123.0), (('Chandigarh', 'India'), 296595.0), (('Charkhi Dadri', 'India'), 386963.0), (('Chatra', 'India'), 168316.0), (('Chennai', 'India'), 55312725.0), (('Cherthala', 'India'), 203426.0), (('Chikkamagaluru', 'India'), 427124.0), (('Chilakaluripet', 'India'), 1078886.0), (('Chirala', 'India'), 169300.0), (('Chirkunda', 'India'), 246475.0), (('Chirmiri', 'India'), 916724.0), (('Chittoor', 'India'), 414712.0), (('Chittur-Thathamangalam', 'India'), 355379.0), (('Cuttack', 'India'), 373231.0), (('Dalli-Rajhara', 'India'), 774804.0), (('Darbhanga', 'India'), 1108569.0), (('Darjiling', 'India'), 859471.0), (('Davanagere', 'India'), 3332 ...
